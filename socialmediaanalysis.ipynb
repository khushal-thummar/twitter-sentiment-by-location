# %%
# !pip install tweepy pandas textblob vaderSentiment matplotlib seaborn

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# !python -m nltk.downloader vader_lexicon
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()

# %%
texts = ["This movie was fantastic!",
         "I didn't like the ending of this book at all.",
         "The weather today is just okay."]

for text in texts:
    scores = sia.polarity_scores(text)
    print(f"Text: {text}")
    print(f"Sentiment Scores: {scores}")
    print(f"Overall Sentiment: {'Positive' if scores['compound'] > 0 else ('Negative' if scores['compound'] < 0 else 'Neutral')}")
    print()
# Out:
# Text: This movie was fantastic!
# Sentiment Scores: {'neg': 0.0, 'neu': 0.435, 'pos': 0.565, 'compound': 0.5983}
# Overall Sentiment: Positive
#
# Text: I didn't like the ending of this book at all.
# Sentiment Scores: {'neg': 0.209, 'neu': 0.791, 'pos': 0.0, 'compound': -0.2755}
# Overall Sentiment: Negative
#
# Text: The weather today is just okay.
# Sentiment Scores: {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.2263}
# Overall Sentiment: Positive

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import tweepy
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

nltk.download('vader_lexicon', quiet=True)
sia = SentimentIntensityAnalyzer()

query = "SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"New York\" ORDER BY tweet_date DESC;"
num_tweets = 1000

print(f"Query: {query}")
print(f"Number of Tweets: {num_tweets}")
results = execute_query(query, limit=num_tweets)
df = pd.DataFrame(results)

if 'tweet_text' in df.columns:
     df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])

else:
     print("Error: 'tweet_text' column not found in DataFrame")
# Out:
# Query: SELECT tweet_text, tweet_date, location FROM tweets WHERE location = "New York" ORDER BY tweet_date DESC;
# Number of Tweets: 1000

# %%
import pandas as pd

def execute_query(query, limit=None):
    data = {'tweet_text': ['This is a sample tweet.', 'Another tweet about New York.', 'A positive tweet!'],
            'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
            'location': ['New York', 'New York', 'New York']}
    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

nltk.download('vader_lexicon', quiet=True)
sia = SentimentIntensityAnalyzer()

query = "SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"London\" ORDER BY tweet_date DESC;"
num_tweets = 100

print(f"Query: {query}")
print(f"Number of Tweets: {num_tweets}")


def execute_query(query, limit=None):
    data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
            'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
            'location': ['London', 'London', 'London']}
    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')

results = execute_query(query, limit=num_tweets)
df = pd.DataFrame(results)

if 'tweet_text' in df.columns:
     df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])

else:
     print("Error: 'tweet_text' column not found in DataFrame")
# Out:
# Query: SELECT tweet_text, tweet_date, location FROM tweets WHERE location = "London" ORDER BY tweet_date DESC;
# Number of Tweets: 100

# %%
def execute_query(query, limit=None):
    if "London" in query:
        data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['London', 'London', 'London']}
    elif "New York" in query:
        data = {'tweet_text': ['This is a sample tweet about New York.', 'Another tweet about New York.', 'A positive tweet about New York!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],

                'location': ['New York', 'New York', 'New York']}
    else:
        data = {'tweet_text': [], 'tweet_date': [], 'location': []}

    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Download required NLTK data
nltk.download('vader_lexicon', quiet=True)
sia = SentimentIntensityAnalyzer()

# Example query and number of tweets (replace with your actual query and number)
query = "SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"London\" ORDER BY tweet_date DESC;"
num_tweets = 200

print(f"Query: {query}")
print(f"Number of Tweets: {num_tweets}")


def execute_query(query, limit=None):
    if "London" in query:
        data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['London', 'London', 'London']}
    elif "New York" in query:
        data = {'tweet_text': ['This is a sample tweet about New York.', 'Another tweet about New York.', 'A positive tweet about New York!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['New York', 'New York', 'New York']}
    else:
        data = {'tweet_text': [], 'tweet_date': [], 'location': []}

    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')

results = execute_query(query, limit=num_tweets)
df = pd.DataFrame(results)

if 'tweet_text' in df.columns:
    df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])

    overall_sentiment = df['Sentiment'].mean()
    location = query.split('WHERE location = ')[1].replace('\"','').replace(';','')
    print(f"Overall Sentiment for '{location}': {overall_sentiment}")

    def categorize_sentiment(score):
        if score >= 0.05:
            return 'Positive'
        elif score <= -0.05:
            return 'Negative'
        else:
            return 'Neutral'

    df['Sentiment Category'] = df['Sentiment'].apply(categorize_sentiment)
    print(df.head())

    # 5. Improved Visualization
    plt.figure(figsize=(10, 6))
    sns.histplot(df['Sentiment'], kde=True, bins=20)
    plt.title('Distribution of Sentiment Scores for Tweets about ' + location)
    plt.xlabel('Sentiment Score')
    plt.ylabel('Frequency')
    plt.axvline(overall_sentiment, color='red', linestyle='dashed', linewidth=2, label=f"Overall Sentiment ({overall_sentiment:.2f})")
    plt.legend()
    plt.show()

    # 6. Wordcloud (if 'Tweet' column exists, otherwise use 'tweet_text')
    text_column = 'Tweet' if 'Tweet' in df.columns else 'tweet_text'
    text = " ".join(str(tweet) for tweet in df[text_column])
    wordcloud = WordCloud(width=800, height=400).generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

else:
    print("Error: 'tweet_text' column not found in DataFrame")
# Out:
# Query: SELECT tweet_text, tweet_date, location FROM tweets WHERE location = "London" ORDER BY tweet_date DESC;
# Number of Tweets: 200
# Overall Sentiment for 'London ORDER BY tweet_date DESC': 0.19943333333333335
#                              tweet_text  tweet_date location  Sentiment  \
# 0  This is a sample tweet about London.  2024-04-27   London     0.0000
# 1           Another tweet about London.  2024-04-26   London     0.0000
# 2        A positive tweet about London!  2024-04-25   London     0.5983
#
#   Sentiment Category
# 0            Neutral
# 1            Neutral
# 2           Positive

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Download required NLTK data (if not already downloaded)
nltk.download('vader_lexicon', quiet=True)
sia = SentimentIntensityAnalyzer()

# Example query and number of tweets (replace with your actual query and number)
query = "SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"London\" ORDER BY tweet_date DESC;"  # Example query
num_tweets = 200  # Example number of tweets

print(f"Query: {query}")
print(f"Number of Tweets: {num_tweets}")

# ... (Your execute_query function remains the same) ...


results = execute_query(query, limit=num_tweets)
df = pd.DataFrame(results)

if 'tweet_text' in df.columns:
    df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])

    overall_sentiment = df['Sentiment'].mean()
    location = query.split('WHERE location = ')[1].replace('\"','').replace(';','')
    print(f"Overall Sentiment for '{location}': {overall_sentiment}")

    # Categorize sentiment
    def categorize_sentiment(score):
        if score >= 0.05:
            return 'Positive'
        elif score <= -0.05:
            return 'Negative'
        else:
            return 'Neutral'

    df['Sentiment Category'] = df['Sentiment'].apply(categorize_sentiment)
    print(df.head())

    # Plotting sentiment distribution
    plt.figure(figsize=(10, 6))
    sns.histplot(df['Sentiment'], kde=True, bins=20)
    plt.title('Distribution of Sentiment Scores for Tweets about ' + location)
    plt.xlabel('Sentiment Score')
    plt.ylabel('Frequency')
    plt.axvline(overall_sentiment, color='red', linestyle='dashed', linewidth=2, label=f"Overall Sentiment ({overall_sentiment:.2f})")
    plt.legend()
    plt.show()

    # Create Wordcloud
    text = " ".join(str(tweet) for tweet in df['tweet_text']) # Assuming 'tweet_text' column exists
    wordcloud = WordCloud(width=800, height=400).generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

else:
    print("Error: 'tweet_text' column not found in DataFrame")
# Out:
# Query: SELECT tweet_text, tweet_date, location FROM tweets WHERE location = "London" ORDER BY tweet_date DESC;
# Number of Tweets: 200
# Overall Sentiment for 'London ORDER BY tweet_date DESC': 0.19943333333333335
#                              tweet_text  tweet_date location  Sentiment  \
# 0  This is a sample tweet about London.  2024-04-27   London     0.0000
# 1           Another tweet about London.  2024-04-26   London     0.0000
# 2        A positive tweet about London!  2024-04-25   London     0.5983
#
#   Sentiment Category
# 0            Neutral
# 1            Neutral
# 2           Positive

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

nltk.download('vader_lexicon', quiet=True)
sia = SentimentIntensityAnalyzer()

def execute_query(query, limit=None):
    if "London" in query:
        data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['London', 'London', 'London']}
    elif "New York" in query:
        data = {'tweet_text': ['This is a sample tweet about New York.', 'Another tweet about New York.', 'A positive tweet about New York!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['New York', 'New York', 'New York']}
    elif "Paris" in query:
        data = {'tweet_text': ['This is a sample tweet about Paris.', 'Another tweet about Paris.', 'A negative tweet about Paris!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Paris', 'Paris', 'Paris']}
    elif "Berlin" in query:
        data = {'tweet_text': ['This is a sample tweet about Berlin.', 'Another tweet about Berlin.', 'A neutral tweet about Berlin!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Berlin', 'Berlin', 'Berlin']}
    else:
        data = {'tweet_text': [], 'tweet_date': [], 'location': []}

    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')

def analyze_location(query, num_tweets):
    results = execute_query(query, limit=num_tweets)
    df = pd.DataFrame(results)

    if 'tweet_text' in df.columns:
        df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])

        overall_sentiment = df['Sentiment'].mean()
        location = query.split('WHERE location = ')[1].replace('\"', '').replace(';', '')
        print(f"Overall Sentiment for '{location}': {overall_sentiment}")

        if overall_sentiment > 0.05:
            print("Positive Sentiment")
        elif overall_sentiment < -0.05:
            print("Negative Sentiment")
        else:
            print("Neutral Sentiment")

    else:
        print("Error: 'tweet_text' column not found in DataFrame")

locations = [
    ("London", 200),
    ("New York", 500),
    ("Paris", 300),
    ("Berlin", 250)
]

for location, num_tweets in locations:
    query = f"SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"{location}\" ORDER BY tweet_date DESC;"
    analyze_location(query, num_tweets)
# Out:
# Overall Sentiment for 'London ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'New York ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'Paris ORDER BY tweet_date DESC': -0.2038
# Negative Sentiment
# Overall Sentiment for 'Berlin ORDER BY tweet_date DESC': 0.0
# Neutral Sentiment

# %%
# prompt: now?

import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Download required NLTK data (if not already downloaded)
nltk.download('vader_lexicon', quiet=True)
sia = SentimentIntensityAnalyzer()

def execute_query(query, limit=None):
    # This function now handles multiple locations
    if "London" in query:
        data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['London', 'London', 'London']}
    elif "New York" in query:
        data = {'tweet_text': ['This is a sample tweet about New York.', 'Another tweet about New York.', 'A positive tweet about New York!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['New York', 'New York', 'New York']}
    elif "Paris" in query:
        data = {'tweet_text': ['This is a sample tweet about Paris.', 'Another tweet about Paris.', 'A negative tweet about Paris!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Paris', 'Paris', 'Paris']}
    elif "Berlin" in query:
        data = {'tweet_text': ['This is a sample tweet about Berlin.', 'Another tweet about Berlin.', 'A neutral tweet about Berlin!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Berlin', 'Berlin', 'Berlin']}
    else:
        data = {'tweet_text': [], 'tweet_date': [], 'location': []}

    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')


def analyze_location(query, num_tweets):
    results = execute_query(query, limit=num_tweets)
    df = pd.DataFrame(results)

    if 'tweet_text' in df.columns:
        df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])
        overall_sentiment = df['Sentiment'].mean()
        location = query.split('WHERE location = ')[1].replace('\"', '').replace(';', '')
        print(f"Overall Sentiment for '{location}': {overall_sentiment}")

        if overall_sentiment > 0.05:
            print("Positive Sentiment")
        elif overall_sentiment < -0.05:
            print("Negative Sentiment")
        else:
            print("Neutral Sentiment")

        plt.figure(figsize=(8, 6))
        sns.histplot(df['Sentiment'], kde=True, bins=20)
        plt.title(f'Sentiment Distribution for {location}')
        plt.xlabel('Sentiment Score')
        plt.ylabel('Frequency')
        plt.axvline(overall_sentiment, color='red', linestyle='dashed', linewidth=1.5, label=f"Overall Sentiment ({overall_sentiment:.2f})")
        plt.legend()
        plt.show()

    else:
        print("Error: 'tweet_text' column not found in DataFrame")

locations = [
    ("London", 200),
    ("New York", 500),
    ("Paris", 300),
    ("Berlin", 250)
]

for location, num_tweets in locations:
    query = f"SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"{location}\" ORDER BY tweet_date DESC;"
    analyze_location(query, num_tweets)
# Out:
# Overall Sentiment for 'London ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'New York ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'Paris ORDER BY tweet_date DESC': -0.2038
# Negative Sentiment
# Overall Sentiment for 'Berlin ORDER BY tweet_date DESC': 0.0
# Neutral Sentiment

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Install necessary libraries (if not already installed)
# !pip install pandas matplotlib seaborn wordcloud

# Download required NLTK data (if not already downloaded)
nltk.download('vader_lexicon', quiet=True)

sia = SentimentIntensityAnalyzer()

def execute_query(query, limit=None):
    # This function now handles multiple locations
    if "London" in query:
        data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['London', 'London', 'London']}
    elif "New York" in query:
        data = {'tweet_text': ['This is a sample tweet about New York.', 'Another tweet about New York.', 'A positive tweet about New York!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['New York', 'New York', 'New York']}
    elif "Paris" in query:
        data = {'tweet_text': ['This is a sample tweet about Paris.', 'Another tweet about Paris.', 'A negative tweet about Paris!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Paris', 'Paris', 'Paris']}
    elif "Berlin" in query:
        data = {'tweet_text': ['This is a sample tweet about Berlin.', 'Another tweet about Berlin.', 'A neutral tweet about Berlin!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Berlin', 'Berlin', 'Berlin']}
    else:
        data = {'tweet_text': [], 'tweet_date': [], 'location': []}

    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')


def analyze_location(query, num_tweets):
    results = execute_query(query, limit=num_tweets)
    df = pd.DataFrame(results)

    if 'tweet_text' in df.columns:
        df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])
        overall_sentiment = df['Sentiment'].mean()
        location = query.split('WHERE location = ')[1].replace('\"', '').replace(';', '')
        print(f"Overall Sentiment for '{location}': {overall_sentiment}")

        if overall_sentiment > 0.05:
            print("Positive Sentiment")
        elif overall_sentiment < -0.05:
            print("Negative Sentiment")
        else:
            print("Neutral Sentiment")

        plt.figure(figsize=(8, 6))
        sns.histplot(df['Sentiment'], kde=True, bins=20)
        plt.title(f'Sentiment Distribution for {location}')
        plt.xlabel('Sentiment Score')
        plt.ylabel('Frequency')
        plt.axvline(overall_sentiment, color='red', linestyle='dashed', linewidth=1.5, label=f"Overall Sentiment ({overall_sentiment:.2f})")
        plt.legend()
        plt.show()

        # Wordcloud
        text = " ".join(str(tweet) for tweet in df['tweet_text'])
        wordcloud = WordCloud(width=800, height=400).generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()

    else:
        print("Error: 'tweet_text' column not found in DataFrame")

locations = [
    ("London", 200),
    ("New York", 500),
    ("Paris", 300),
    ("Berlin", 250)
]

for location, num_tweets in locations:
    query = f"SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"{location}\" ORDER BY tweet_date DESC;"
    analyze_location(query, num_tweets)
# Out:
# ...
# Overall Sentiment for 'London ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'New York ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'Paris ORDER BY tweet_date DESC': -0.2038
# Negative Sentiment
# Overall Sentiment for 'Berlin ORDER BY tweet_date DESC': 0.0
# Neutral Sentiment

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# !pip install pandas matplotlib seaborn wordcloud

nltk.download('vader_lexicon', quiet=True)

sia = SentimentIntensityAnalyzer()

def execute_query(query, limit=None):
    if "London" in query:
        data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['London', 'London', 'London']}
    elif "New York" in query:
        data = {'tweet_text': ['This is a sample tweet about New York.', 'Another tweet about New York.', 'A positive tweet about New York!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['New York', 'New York', 'New York']}
    elif "Paris" in query:
        data = {'tweet_text': ['This is a sample tweet about Paris.', 'Another tweet about Paris.', 'A negative tweet about Paris!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Paris', 'Paris', 'Paris']}
    elif "Berlin" in query:
        data = {'tweet_text': ['This is a sample tweet about Berlin.', 'Another tweet about Berlin.', 'A neutral tweet about Berlin!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Berlin', 'Berlin', 'Berlin']}
    else:
        data = {'tweet_text': [], 'tweet_date': [], 'location': []}

    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')


def analyze_location(query, num_tweets):
    results = execute_query(query, limit=num_tweets)
    df = pd.DataFrame(results)

    if 'tweet_text' in df.columns:
        df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])
        overall_sentiment = df['Sentiment'].mean()
        location = query.split('WHERE location = ')[1].replace('\"', '').replace(';', '')
        print(f"Overall Sentiment for '{location}': {overall_sentiment}")

        if overall_sentiment > 0.05:
            print("Positive Sentiment")
        elif overall_sentiment < -0.05:
            print("Negative Sentiment")
        else:
            print("Neutral Sentiment")

        plt.figure(figsize=(8, 6))
        sns.histplot(df['Sentiment'], kde=True, bins=20)
        plt.title(f'Sentiment Distribution for {location}')
        plt.xlabel('Sentiment Score')
        plt.ylabel('Frequency')
        plt.axvline(overall_sentiment, color='red', linestyle='dashed', linewidth=1.5, label=f"Overall Sentiment ({overall_sentiment:.2f})")
        plt.legend()
        plt.show()

        text = " ".join(str(tweet) for tweet in df['tweet_text'])
        wordcloud = WordCloud(width=800, height=400).generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()

    else:
        print("Error: 'tweet_text' column not found in DataFrame")

locations = [
    ("London", 200),
    ("New York", 500),
    ("Paris", 300),
    ("Berlin", 250)
]

for location, num_tweets in locations:
    query = f"SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"{location}\" ORDER BY tweet_date DESC;"
    analyze_location(query, num_tweets)
# Out:
# ...
# Overall Sentiment for 'London ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'New York ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'Paris ORDER BY tweet_date DESC': -0.2038
# Negative Sentiment
# Overall Sentiment for 'Berlin ORDER BY tweet_date DESC': 0.0
# Neutral Sentiment

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# !pip install pandas matplotlib seaborn wordcloud

nltk.download('vader_lexicon', quiet=True)

sia = SentimentIntensityAnalyzer()

def execute_query(query, limit=None):
    if "London" in query:
        data = {'tweet_text': ['This is a sample tweet about London.', 'Another tweet about London.', 'A positive tweet about London!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['London', 'London', 'London']}
    elif "New York" in query:
        data = {'tweet_text': ['This is a sample tweet about New York.', 'Another tweet about New York.', 'A positive tweet about New York!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['New York', 'New York', 'New York']}
    elif "Paris" in query:
        data = {'tweet_text': ['This is a sample tweet about Paris.', 'Another tweet about Paris.', 'A negative tweet about Paris!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Paris', 'Paris', 'Paris']}
    elif "Berlin" in query:
        data = {'tweet_text': ['This is a sample tweet about Berlin.', 'Another tweet about Berlin.', 'A neutral tweet about Berlin!'],
                'tweet_date': ['2024-04-27', '2024-04-26', '2024-04-25'],
                'location': ['Berlin', 'Berlin', 'Berlin']}
    else:
        data = {'tweet_text': [], 'tweet_date': [], 'location': []}

    df = pd.DataFrame(data)

    if limit:
        return df.head(limit).to_dict('records')

    return df.to_dict('records')


def analyze_location(query, num_tweets):
    results = execute_query(query, limit=num_tweets)
    df = pd.DataFrame(results)

    if 'tweet_text' in df.columns:
        df['Sentiment'] = df['tweet_text'].apply(lambda tweet: sia.polarity_scores(tweet)['compound'])
        overall_sentiment = df['Sentiment'].mean()
        location = query.split('WHERE location = ')[1].replace('\"', '').replace(';', '')
        print(f"Overall Sentiment for '{location}': {overall_sentiment}")

        if overall_sentiment > 0.05:
            print("Positive Sentiment")
        elif overall_sentiment < -0.05:
            print("Negative Sentiment")
        else:
            print("Neutral Sentiment")

        plt.figure(figsize=(8, 6))
        sns.histplot(df['Sentiment'], kde=True, bins=20)
        plt.title(f'Sentiment Distribution for {location}')
        plt.xlabel('Sentiment Score')
        plt.ylabel('Frequency')
        plt.axvline(overall_sentiment, color='red', linestyle='dashed', linewidth=1.5, label=f"Overall Sentiment ({overall_sentiment:.2f})")
        plt.legend()
        plt.show()

        text = " ".join(str(tweet) for tweet in df['tweet_text'])
        wordcloud = WordCloud(width=800, height=400).generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()

    else:
        print("Error: 'tweet_text' column not found in DataFrame")

locations = [
    ("London", 200),
    ("New York", 500),
    ("Paris", 300),
    ("Berlin", 250)
]

for location, num_tweets in locations:
    query = f"SELECT tweet_text, tweet_date, location FROM tweets WHERE location = \"{location}\" ORDER BY tweet_date DESC;"
    analyze_location(query, num_tweets)
# Out:
# ...
# Overall Sentiment for 'London ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'New York ORDER BY tweet_date DESC': 0.19943333333333335
# Positive Sentiment
# Overall Sentiment for 'Paris ORDER BY tweet_date DESC': -0.2038
# Negative Sentiment
# Overall Sentiment for 'Berlin ORDER BY tweet_date DESC': 0.0
# Neutral Sentiment
